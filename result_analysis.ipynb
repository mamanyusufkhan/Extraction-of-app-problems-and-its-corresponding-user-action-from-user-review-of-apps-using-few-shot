# %%
import pandas as pd

# %%
df = pd.read_csv("/content/selected_reviews.csv")

# %%
df
# Out:
#                                                content  Identified  Keyword   \
# 0    I had the app for long time but lately have st...           0         0
# 1                               Too complicated to use           0         0
# 2    Purchased by premium, getting error can not sy...           1         0
# 3                            It's takes a lot of space           0         0
# 4    After installing the app, i check to see if my...           0         1
# ..                                                 ...         ...       ...
# 195  I used to like, even love this app. It was gre...           1         1
# 196                 For task duration you need premium           0         0
# 197                   Lack of reminder in free version           0         0
# 198  Any event with repeat will not save. New updat...           0         0
# 199                           It doesn't work at all!!           0         0
#
#      Predicted
# 0            0
# ...

# %%
from sklearn.metrics import confusion_matrix

# %%
y_true = df["Identified"]
y_pred = df["Predicted"]

# %%
tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

# %%
print(tn, fp, fn, tp)
# Out:
# 130 15 8 47

# %%
df_2 = df[df["Keyword "] == 1]
y_true = df_2["Identified"]
y_pred = df_2["Predicted"]

# %%
df_2
# Out:
#                                                content  Identified  Keyword   \
# 4    After installing the app, i check to see if my...           0         1
# 9    Poor service. I purchased the premium version,...           1         1
# 29   while using the habbit feature, you can add mu...           1         1
# 62   Dear developers, thank you for deleting all my...           1         1
# 65   I want to love this app, but every time I use ...           1         1
# 71   It does not send me notification when i open t...           0         1
# 78   Now down to 1 star for the unappreciated bilin...           0         1
# 81   App starts ads after 1 month and opens wanting...           0         1
# 84                       Can't print after last update           1         1
# 88   It used to be great but ever since it updated ...           1         1
# 117  i paid for full version but im unable to resto...           1         1
# ...

# %%
tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

# %%
print(tn, fp, fn, tp)
# Out:
# 6 2 2 13

# %%
df_3 = df[df["Keyword "] == 0]
y_true = df_2["Identified"]
y_pred = df_2["Predicted"]

# %%
tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

# %%
print(tn, fp, fn, tp)
# Out:
# 124 13 6 34

# %%
def construct_accuracy_precision_and_recall(tn, fp, fn, tp):
  accuracy = (tp + tn)/(tp + fp + fn + tn)
  print("Accuracy: " + str(accuracy))


  if tp == 0 and fp == 0:
    precision = 0
  else:
    precision = tp / (tp + fp)
  print("Precision: "+ str(precision))


  recall = tp / (tp + fn)
  print("Recall: "+ str(recall))

# %%
print("Overall:")
construct_accuracy_precision_and_recall(130, 15, 8, 47)
# Out:
# Overall:
# Accuracy: 0.885
# Precision: 0.7580645161290323
# Recall: 0.8545454545454545

# %%
print("Keywords:")
construct_accuracy_precision_and_recall(6, 2, 2, 13)
# Out:
# Keywords:
# Accuracy: 0.8260869565217391
# Precision: 0.8666666666666667
# Recall: 0.8666666666666667

# %%
print("Without Keywords: ")
construct_accuracy_precision_and_recall(124, 13, 6, 34)
# Out:
# Without Keywords:
# Accuracy: 0.8926553672316384
# Precision: 0.723404255319149
# Recall: 0.85

# %%
print("Caspar Overall:")
construct_accuracy_precision_and_recall(161, 1, 25, 13)
# Out:
# Caspar Overall:
# Accuracy: 0.87
# Precision: 0.9285714285714286
# Recall: 0.34210526315789475

# %%
print("Caspar Keywords: ")
construct_accuracy_precision_and_recall(33, 1, 16, 13)
# Out:
# Caspar Keywords:
# Accuracy: 0.7301587301587301
# Precision: 0.9285714285714286
# Recall: 0.4482758620689655

# %%
print("Caspar Without Keywords: ")
construct_accuracy_precision_and_recall(128, 0, 9, 0)
# Out:
# Caspar Without Keywords:
# Accuracy: 0.9343065693430657
# Precision: 0
# Recall: 0.0
